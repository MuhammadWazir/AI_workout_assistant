# %%
import pandas as pd

# %%
df_train = pd.read_csv('/content/drive/MyDrive/AI_workout_assistant/models/Lunges/train.csv')
df_train.columns
df_test = pd.read_csv('/content/drive/MyDrive/AI_workout_assistant/models/Lunges/test.csv')
df_test.columns
# Out:
# Index(['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x',
#        'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v',
#        'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z',
#        'right_shoulder_v', 'left_hip_x', 'left_hip_y', 'left_hip_z',
#        'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z',
#        'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z',
#        'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z',
#        'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z',
#        'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z',
#        'right_ankle_v', 'left_heel_x', 'left_heel_y', 'left_heel_z',
#        'left_heel_v', 'right_heel_x', 'right_heel_y', 'right_heel_z',
#        'right_heel_v', 'left_foot_index_x', 'left_foot_index_y',
#        'left_foot_index_z', 'left_foot_index_v', 'right_foot_index_x',
#        'right_foot_index_y', 'right_foot_index_z', 'right_foot_index_v'],
# ...

# %%
df_train.shape
df_train.info()
df_train.describe()
df_test.shape
df_test.info()
df_test.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17907 entries, 0 to 17906
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   label               17907 non-null  object
#  1   nose_x              17907 non-null  float64
#  2   nose_y              17907 non-null  float64
#  3   nose_z              17907 non-null  float64
#  4   nose_v              17907 non-null  float64
#  5   left_shoulder_x     17907 non-null  float64
#  6   left_shoulder_y     17907 non-null  float64
#  7   left_shoulder_z     17907 non-null  float64
#  8   left_shoulder_v     17907 non-null  float64
#  9   right_shoulder_x    17907 non-null  float64
#  10  right_shoulder_y    17907 non-null  float64
#  11  right_shoulder_z    17907 non-null  float64
#  12  right_shoulder_v    17907 non-null  float64
#  13  left_hip_x          17907 non-null  float64
#  14  left_hip_y          17907 non-null  float64
# ...

# %%
df_train.isnull().sum()
df_test.isnull().sum()
# Out:
# label                 0
# nose_x                0
# nose_y                0
# nose_z                0
# nose_v                0
# left_shoulder_x       0
# left_shoulder_y       0
# left_shoulder_z       0
# left_shoulder_v       0
# right_shoulder_x      0
# right_shoulder_y      0
# right_shoulder_z      0
# right_shoulder_v      0
# left_hip_x            0
# left_hip_y            0
# left_hip_z            0
# left_hip_v            0
# right_hip_x           0
# right_hip_y           0
# right_hip_z           0
# right_hip_v           0
# left_knee_x           0
# left_knee_y           0
# left_knee_z           0
# left_knee_v           0
# right_knee_x          0
# right_knee_y          0
# right_knee_z          0
# right_knee_v          0
# left_ankle_x          0
# left_ankle_y          0
# left_ankle_z          0
# left_ankle_v          0
# right_ankle_x         0
# right_ankle_y         0
# right_ankle_z         0
# right_ankle_v         0
# left_heel_x           0
# ...

# %%
df_train["label"].value_counts()
df_test["label"].value_counts()
# Out:
# label
# L    561
# C    546
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

#select the coordinates as features
X_train= df_train[['left_hip_x', 'left_hip_y', 'left_hip_z',
       'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z',
       'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z',
       'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z',
       'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z',
       'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z',
       'right_ankle_v', 'left_heel_x', 'left_heel_y', 'left_heel_z',
       'left_heel_v', 'right_heel_x', 'right_heel_y', 'right_heel_z',
       'right_heel_v', 'left_foot_index_x', 'left_foot_index_y',
       'left_foot_index_z', 'left_foot_index_v', 'right_foot_index_x',
       'right_foot_index_y', 'right_foot_index_z', 'right_foot_index_v']]

Y_train= df_train['label']

X_test= df_test[[ 'left_hip_x', 'left_hip_y', 'left_hip_z',
       'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z',
       'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z',
       'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z',
       'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z',
       'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z',
       'right_ankle_v', 'left_heel_x', 'left_heel_y', 'left_heel_z',
       'left_heel_v', 'right_heel_x', 'right_heel_y', 'right_heel_z',
       'right_heel_v', 'left_foot_index_x', 'left_foot_index_y',
       'left_foot_index_z', 'left_foot_index_v', 'right_foot_index_x',
       'right_foot_index_y', 'right_foot_index_z', 'right_foot_index_v']]
Y_test= df_test['label']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from tensorflow.keras.optimizers import Adam

# Encode using .replace()
Y_train = Y_train.replace({"C": 1, "L": 0})
Y_test = Y_test.replace({"C": 1, "L": 0})

def build_5_layer_dnn(input_dim):
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification output

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
def build_5_layer_dnn_with_dropout(input_dim):
  model = Sequential()
  model.add(Input(shape=(input_dim,)))
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.1))
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(optimizer=Adam(learning_rate=0.001),
                loss='binary_crossentropy',
                metrics=['accuracy'])
  return model
def build_7_layer_dnn(input_dim):
  model = Sequential()
  model.add(Input(shape=(input_dim,)))
  model.add(Dense(512, activation='relu'))
  model.add(Dense(256, activation='relu'))
  model.add(Dense(128, activation='relu'))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(16, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(optimizer=Adam(learning_rate=0.001),
                loss='binary_crossentropy',
                metrics=['accuracy'])
  return model
def build_7_layer_dnn_with_dropout(input_dim):
  model = Sequential()
  model.add(Input(shape=(input_dim,)))
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.1))
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(64, activation='relu'))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(16, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(optimizer=Adam(learning_rate=0.001),
                loss='binary_crossentropy',
                metrics=['accuracy'])
  return model

clf1 = LogisticRegression(solver='lbfgs', random_state=1, max_iter=400)
clf2 = DecisionTreeClassifier(random_state=1)
clf3 = GaussianNB()

# Create and train the Keras neural network for binary classification
dnn_model = build_5_layer_dnn(input_dim=X_train.shape[1])
dnn_model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=0)

dnn_5_dropout_model = build_5_layer_dnn_with_dropout(input_dim=X_train.shape[1])
dnn_5_dropout_model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=0)

dnn_7_model = build_7_layer_dnn(input_dim=X_train.shape[1])
dnn_7_model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=0)

dnn_7_dropout_model = build_7_layer_dnn_with_dropout(input_dim=X_train.shape[1])
dnn_7_dropout_model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=0)

# Predict and evaluate each model
dnn_5_dropout_preds = dnn_5_dropout_model.predict(X_test)
dnn_5_dropout_preds = (dnn_5_dropout_preds > 0.5).astype(int)

dnn_7_preds = dnn_7_model.predict(X_test)
dnn_7_preds = (dnn_7_preds > 0.5).astype(int)

dnn_7_dropout_preds = dnn_7_dropout_model.predict(X_test)
dnn_7_dropout_preds = (dnn_7_dropout_preds > 0.5).astype(int)

dnn_preds = dnn_model.predict(X_test)
dnn_preds = (dnn_preds > 0.5).astype(int)  # Convert probabilities to binary predictions

# For Ensemble Voting Classifier (excluding Keras DNN)
eclf = VotingClassifier(estimators=[
        ('lr', clf1),
        ('dt', clf2),
        ('gnb', clf3)
    ], voting='soft')

for clf, label in zip([clf1, clf2, clf3, eclf],
        ['Logistic Regression', 'Decision Tree', 'Gaussian NB', 'Ensemble']):
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    accuracy = accuracy_score(Y_test, Y_pred)
    print(f"Accuracy: {accuracy:.2f} [{label}]")

# Evaluate the Keras DNN model separately
dnn_accuracy = accuracy_score(Y_test, dnn_preds)
print(f"Accuracy: {dnn_accuracy:.2f} [5 layer DNN]")

dnn_5_dropout_accuracy = accuracy_score(Y_test, dnn_5_dropout_preds)
print(f"Accuracy: {dnn_5_dropout_accuracy:.2f} [5-Layer DNN with Dropout]")

dnn_7_accuracy = accuracy_score(Y_test, dnn_7_preds)
print(f"Accuracy: {dnn_7_accuracy:.2f} [7-Layer DNN]")

dnn_7_dropout_accuracy = accuracy_score(Y_test, dnn_7_dropout_preds)
print(f"Accuracy: {dnn_7_dropout_accuracy:.2f} [7-Layer DNN with Dropout]")
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Accuracy: 0.84 [Logistic Regression]
# Accuracy: 0.69 [Decision Tree]
# Accuracy: 0.56 [Gaussian NB]
# Accuracy: 0.73 [Ensemble]
# Accuracy: 0.84 [5 layer DNN]
# Accuracy: 0.80 [5-Layer DNN with Dropout]
# Accuracy: 0.79 [7-Layer DNN]
# Accuracy: 0.74 [7-Layer DNN with Dropout]

# %%
import pickle

# Save the model to a file using pickle
with open('/content/drive/MyDrive/AI_workout_assistant/models/Lunges/lunges_model_logistic_regression.pkl', 'wb') as file:
    pickle.dump(clf1, file)
